# %%
# !pip install -q condacolab
import condacolab
condacolab.install()

# %%
import condacolab
condacolab.check()

# !mamba install python=3.11 -y

# %%
# !git clone https://github.com/ccchloe510/mase.git

# %%
# !python -m pip install -e ./mase
